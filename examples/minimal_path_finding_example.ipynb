# %%
from pyorps import RasterGraph

# %%
cost_file_path = r"data\cost_assumptions\cost_assumptions.csv"
base_file_url = "https://www.gds.hessen.de/wfs2/aaa-suite/cgi-bin/alkis/vereinf/wfs"

# %%
box_tuple = (471228, 5592632, 474176, 5594879)

# Example usage
base_file = {
    "url": base_file_url,
    "layer": "ave_Nutzung",
}

delta = 800
source_coords = (box_tuple[0] + delta, box_tuple[1] + delta)
target_coords = (box_tuple[2] - delta, box_tuple[3] - delta)

raster_graph = RasterGraph(
    dataset_source=base_file,
    source_coords=source_coords,
    target_coords=target_coords,
    search_space_buffer_m=500,  # Use search-specific buffer
    neighborhood_str="r2",
    graph_api='rustworkx',
    cost_assumptions=cost_file_path,
    bbox=box_tuple,
)

# %%
route_result = raster_graph.find_route()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 route_result = raster_graph.find_route()
#
# File ~\Documents\3_python_projects\pyorps\pyorps\graph\raster_graph.py:339, in RasterGraph.find_route(self, source, target, algorithm, calculate_metrics, pairwise)
#     337 # Case 1: Single source, single target -> single path
#     338 if not is_source_list and not is_target_list:
# --> 339     return self._create_path_result(path_indices, source, target, algorithm, calculate_metrics)
#     341 # Case 2 & 3: Multiple paths
#     342 # For single source + multiple targets OR multiple sources + multiple targets
#     343 results = []
#
# File ~\Documents\3_python_projects\pyorps\pyorps\graph\raster_graph.py:375, in RasterGraph._create_path_result(self, path_indices, source, target, algorithm, calculate_metrics)
#     361 """
#     362 Helper method to create a path result dictionary from path indices.
#     363
#    (...)    372     Dictionary containing path information
#     373 """
#     374 # Convert path indices to coordinates
# --> 375 path_coords = self.get_coords_from_node_indices(path_indices)
#     377 # Calculate the euclidean distance
#     378 euclidean_distance = np.sqrt((path_coords[0][0] - path_coords[0][1]) ** 2 +
#     379                              (path_coords[-1][0] - path_coords[-1][1]) ** 2)
#
# File ~\Documents\3_python_projects\pyorps\pyorps\graph\raster_graph.py:289, in RasterGraph.get_coords_from_node_indices(self, node_indices)
#     286 _, rows, cols = self.raster_handler.data.shape
#     288 # Convert 1D indices to 2D indices using unravel_index
# --> 289 indices_2d = np.array(np.unravel_index(node_indices, (rows, cols))).T
#     291 # Convert 2D indices to coordinates
#     292 coords = self.raster_handler.indices_to_coords(indices_2d)
#
# TypeError: only int indices permitted

# %%
raster_graph.plot_paths()

# %%
route_result
# Out:
# Path(source=(472028, 5593432), target=(473376, 5594079), algorithm='dijkstra', graph_api='networkit', path_indices=[2693656, 2693657, 2693658, 2693659, 2693660, 2693661, 2693662, 2693663, 2693664, 2693665, 2693666, 2693667, 2693668, 2693669, 2693670, 2693671, 2693672, 2693673, 2693674, 2693675, 2693676, 2693677, 2693678, 2693679, 2693680, 2693681, 2693682, 2693683, 2693684, 2693685, 2693686, 2693687, 2693688, 2693689, 2693690, 2693691